# %%
import pandas as pd
import os
import zipfile as zp

import gc



#zip = zp.ZipFile("/content/drive/MyDrive/Team 55 [NEW]/Data/FEMA_TEST/FEMA/IndividualsAndHouseholdsProgramValidRegistrations.zip")
#zip.extractall("/content/drive/MyDrive/Team 55 [NEW]/Data/FEMA_TEST/FEMA/")



def onlyKat(loc):
  res = []
  file_loc =  loc
  with open(file_loc) as f:
    df=pd.read_csv(f, delimiter=',', low_memory= False, chunksize = 1000000 )

    for babydf in df:
      print(babydf.shape)
      code_a = babydf[babydf["disasterNumber"] == 1603]
      code_b = babydf[babydf["disasterNumber"] == 3212] 
      code_ab = pd.concat([code_a,code_b])

      res.append(code_ab)
      del(babydf)
      gc.collect()
      babydf=pd.DataFrame()

    del(df)
    gc.collect()
    df=pd.DataFrame()

    return res
    

file = "/content/drive/MyDrive/Team 55 [NEW]/Data/FEMA_TEST/FEMA/IndividualsAndHouseholdsProgramValidRegistrations.csv"
outputfile = "/content/drive/MyDrive/Team 55 [NEW]/Data/FEMA_TEST/FEMA/IndividualsAndHouseholdsProgramValidRegistrations_katOnly.csv"
#onlyKat(file).to_csv(outputfile, index=False)

df_concat = pd.concat(onlyKat(file)).to_csv(outputfile, index=False)
# Out:
# (1000000, 71)
# (1000000, 71)
# (1000000, 71)
# (1000000, 71)
# (1000000, 71)
# (1000000, 71)
# (1000000, 71)
# (1000000, 71)
# (1000000, 71)
# (1000000, 71)
# (1000000, 71)
# (1000000, 71)
# (1000000, 71)
# (1000000, 71)
# (1000000, 71)
# (1000000, 71)
# (1000000, 71)
# (1000000, 71)
# (1000000, 71)
# (1000000, 71)
# (509005, 71)
