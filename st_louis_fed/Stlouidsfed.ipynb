# %%
from google.colab import drive
drive.mount('/content/drive')
import numpy as np 
import pandas as pd 
import glob 
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Mounted at /content/drive

# %%
 df_ascencion = pd.read_csv('/content/drive/MyDrive/Team 55/Team 55 [NEW]/Data/StLouis fed Housing data / All-Transactions House Price Index for Ascension Parish, LA.csv')
df_east_feliciana = pd.read_csv('/content/drive/MyDrive/Team 55/Team 55 [NEW]/Data/StLouis fed Housing data / House Price Index for East Feliciana Parish, LA (ATNHPIUS22037A).csv')

# %%
df_st_john_baptist = pd.read_csv('/content/drive/MyDrive/Team 55 [NEW]/Data/StLouis fed Housing data / House Price Index for St. John the Baptist Parish, LA.csv')
df_west_batonrouge = pd.read_csv('/content/drive/MyDrive/Team 55 [NEW]/Data/StLouis fed Housing data / House Price Index for West Baton Rouge Parish, LA.csv')
Median_house_income = pd.read_csv('/content/drive/MyDrive/Team 55 [NEW]/Data/StLouis fed Housing data / Median Household Income in Louisiana.csv')
hpi_La =pd.read_csv('/content/drive/MyDrive/Team 55 [NEW]/Data/StLouis fed Housing data /House Price Index For Lousiana.csv')
df_batonrouge = pd.read_csv('/content/drive/MyDrive/Team 55 [NEW]/Data/StLouis fed Housing data /House Price Index for Baton Rouge, LA (MSA) (ATNHPIUS12940Q).csv')
df_caddo = pd.read_csv('/content/drive/MyDrive/Team 55 [NEW]/Data/StLouis fed Housing data /House Price Index for Caddo Parish, LA.csv')
df_iberville = pd.read_csv('/content/drive/MyDrive/Team 55 [NEW]/Data/StLouis fed Housing data /House Price Index for Iberville Parish, LA.csv')
df_livingston = pd.read_csv('/content/drive/MyDrive/Team 55 [NEW]/Data/StLouis fed Housing data /House Price Index for Livingston Parish, LA .csv')
df_neworleansmetairie = pd.read_csv('/content/drive/MyDrive/Team 55 [NEW]/Data/StLouis fed Housing data /House Price Index for New Orleans-Metairie, LA .csv')
df_plaquemines = pd.read_csv('/content/drive/MyDrive/Team 55 [NEW]/Data/StLouis fed Housing data /House Price Index for Plaquemines Parish, LA.csv')
df_pointe_coupee =pd.read_csv('/content/drive/MyDrive/Team 55 [NEW]/Data/StLouis fed Housing data /House Price Index for Pointe Coupee Parish, LA.csv')
df_shreveport_bossier = pd.read_csv('/content/drive/MyDrive/Team 55 [NEW]/Data/StLouis fed Housing data /House Price Index for Shreveport-Bossier.csv')
df_st_james = pd.read_csv('/content/drive/MyDrive/Team 55 [NEW]/Data/StLouis fed Housing data /House Price Index for St. James Parish, LA .csv')
df_st_tammany = pd.read_csv('/content/drive/MyDrive/Team 55 [NEW]/Data/StLouis fed Housing data /House Price Index for St. Tammany Parish, LA .csv')
df_washington = pd.read_csv('/content/drive/MyDrive/Team 55 [NEW]/Data/StLouis fed Housing data /House Price Index for Washington Parish, LA .csv')
df_west_feliciana = pd.read_csv('/content/drive/MyDrive/Team 55 [NEW]/Data/StLouis fed Housing data /House Price Index for West Feliciana Parish, LA .csv')
df_jefferson=pd.read_csv('/content/drive/MyDrive/Team 55/Team 55 [NEW]/Data/StLouis fed Housing data /House Price index for Jefferson Parrish.csv - ATNHPIUS22051A.csv')

# %%
parrish_list = [df_st_john_baptist,df_west_batonrouge,Median_house_income, hpi_La ,df_batonrouge, df_caddo ,df_iberville, df_livingston, df_neworleansmetairie,df_plaquemines,df_pointe_coupee ,df_shreveport_bossier,df_st_james,
df_st_tammany ,
df_washington ,
df_west_feliciana ,
df_jefferson,]

# %%
result = parrish_list[0]
for i in range(1, len(parrish_list)):
  result = pd.merge(left=result, right=parrish_list[i], on='DATE')

# %%
result
# Out:
#           DATE  ATNHPIUS22095A  ATNHPIUS22121A  MEHOINUSLAA646N  LASTHPI  \
# 0   1993-01-01           76.13           66.55            26312   113.79
# 1   1994-01-01           79.53           70.56            25676   121.57
# 2   1995-01-01           83.65           74.39            27949   126.89
# 3   1996-01-01           87.39           81.21            30262   134.78
# 4   1997-01-01           91.41           86.67            33260   140.68
# 5   1998-01-01           93.41           88.90            31735   147.93
# 6   1999-01-01           97.37           92.31            32654   154.55
# 7   2000-01-01          100.00          100.00            30718   160.11
# 8   2001-01-01          105.42          102.42            33322   168.27
# 9   2002-01-01          109.55          105.63            34008   174.17
# 10  2003-01-01          112.65          107.21            33507   183.22
# 11  2004-01-01          119.24          114.88            36429   192.07
# ...

# %%
test_values = ['Date', "St. John the Baptist Parish", "West Batonrouge Parish", "Median House Income", "HPI La", "Batonrouge Parish", "Caddo Parish", "Iberville Parish", "Livingston Parish", "New Orleans Metairie Parish", "Plaquemines Parish", "Pointe Coupee Parish", "Shreveport Bossier Parish", "St. James Parish", "St. Tammany Parish", "Washington Parish", "West Feliciana Parish", "Jefferson Parish"]
column_mapping = {old_name: new_name for old_name, new_name in zip(result.columns, test_values)}
result = result.rename(columns=column_mapping)
result.columns = test_values

# %%
result['Date']=pd.to_datetime(result['Date'])
result
# Out:
#          Date  St. John the Baptist Parish  West Batonrouge Parish  \
# 0  1993-01-01                        76.13                   66.55
# 1  1994-01-01                        79.53                   70.56
# 2  1995-01-01                        83.65                   74.39
# 3  1996-01-01                        87.39                   81.21
# 4  1997-01-01                        91.41                   86.67
# 5  1998-01-01                        93.41                   88.90
# 6  1999-01-01                        97.37                   92.31
# 7  2000-01-01                       100.00                  100.00
# 8  2001-01-01                       105.42                  102.42
# 9  2002-01-01                       109.55                  105.63
# 10 2003-01-01                       112.65                  107.21
# 11 2004-01-01                       119.24                  114.88
# 12 2005-01-01                       128.26                  116.64
# ...

# %%
filtered_result = result[result['Date'].dt.year >= 2000]

# %%
list1 = filtered_result
list2 = ["Washington Parish", "Orleans Parish", "St. Bernard Parish", "St. Charles Parish", "Jefferson Parish", "Plaquemines Parish", "St. James Parish", "St. John the Baptist Parish", "St. Tammany Parish", "Tangipahoa Parish", "Ascension Parish", "East Baton Rouge Parish", "East Feliciana Parish", "Iberville Parish", "Livingston Parish", "Pointe Coupee Parish", "St. Helena Parish", "West Baton Rouge Parish", "West Feliciana Parish", "Caddo Parish"]

set1 = set(list1)
set2 = set(list2)

difference = set1.difference(set2)

print(difference)  # Output: {'Date', 'HPI La', 'Median House Income', 'New Orleans Metairie Parish', 'Shreveport Bossier Parish', 'Batonrouge Parish'}
# Out:
# {'West Batonrouge Parish', 'HPI La', 'Median House Income', 'Date', 'New Orleans Metairie Parish', 'Batonrouge Parish', 'Shreveport Bossier Parish'}

# %%
filtered_result['Plaquemines Parish']=filtered_result['Plaquemines Parish'].astype(float)
filtered_result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22 entries, 7 to 28
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Date                         22 non-null     datetime64[ns]
#  1   St. John the Baptist Parish  22 non-null     float64
#  2   West Batonrouge Parish       22 non-null     float64
#  3   Median House Income          22 non-null     int64
#  4   HPI La                       22 non-null     float64
#  5   Batonrouge Parish            22 non-null     float64
#  6   Caddo Parish                 22 non-null     float64
#  7   Iberville Parish             22 non-null     float64
#  8   Livingston Parish            22 non-null     float64
#  9   New Orleans Metairie Parish  22 non-null     float64
#  10  Plaquemines Parish           22 non-null     float64
#  11  Pointe Coupee Parish         22 non-null     float64
# ...

# %%
df= filtered_result
df.describe().T
# Out:
#                              count          mean          std       min  \
# St. John the Baptist Parish   22.0    135.503182    17.771572    100.00
# West Batonrouge Parish        22.0    135.350455    19.616202    100.00
# Median House Income           22.0  41711.181818  6788.198664  30718.00
# HPI La                        22.0    236.925455    41.350125    160.11
# Batonrouge Parish             22.0    182.817273    32.264809    125.96
# Caddo Parish                  22.0    137.826818    17.985631    100.00
# Iberville Parish              22.0    133.958636    19.573464    100.00
# Livingston Parish             22.0    139.087273    21.827351    100.00
# New Orleans Metairie Parish   22.0    194.105000    35.367935    128.48
# Plaquemines Parish            22.0    138.805000    17.649930    100.00
# Pointe Coupee Parish          22.0    143.509545    23.150923    100.00
# Shreveport Bossier Parish     22.0    168.459545    25.563824    115.55
# ...

# %%
df['Plaquemines Parish'].astype(float)
# Out:
# 7     100.00
# 8     106.63
# 9     110.85
# 10    115.95
# 11    121.72
# 12    131.30
# 13    142.18
# 14    146.73
# 15    146.53
# 16    143.12
# 17    142.38
# 18    137.97
# 19    140.96
# 20    143.46
# 21    144.90
# 22    143.50
# 23    148.37
# 24    148.50
# 25    152.28
# 26    156.11
# 27    160.43
# 28    169.84
# Name: Plaquemines Parish, dtype: float64

# %%
#'Date', "St. John the Baptist Parish", "West Batonrouge Parish", "Median House Income", "HPI La", "Batonrouge Parish", 
#"Caddo Parish", "Iberville Parish", "Livingston Parish", "New Orleans Metairie Parish", "Plaquemines Parish", "Pointe Coupee Parish", 
#"Shreveport Bossier Parish", "St. James Parish", "St. Tammany Parish", "Washington Parish", "West Feliciana Parish", "Jefferson Parish"
sns.lineplot(x="Date", y='St. John the Baptist Parish', data=df,label='St. John the Baptist Parish')
sns.lineplot(x="Date", y="West Batonrouge Parish", data=df,label='West Batonrouge Parish')
sns.lineplot(x="Date", y= "HPI La", data=df,label=' "HPI La"')
sns.lineplot(x="Date", y="Batonrouge Parish", data=df,label='"Batonrouge Parish"')
sns.lineplot(x="Date", y="Caddo Parish", data=df,label='Caddo Parish')
sns.lineplot(x="Date", y= "New Orleans Metairie Parish", data=df,label='"New Orleans Metairie Parish"')
sns.lineplot(x="Date", y= "Iberville Parish", data=df)
sns.lineplot(x="Date", y= "Livingston Parish", data=df)
#sns.lineplot(x="Date", y=  "Plaquemines Parish", data=df)
sns.lineplot(x="Date", y= "Iberville Parish", data=df)
sns.lineplot(x="Date", y=  "Pointe Coupee Parish", data=df)
sns.lineplot(x="Date", y= "Shreveport Bossier Parish", data=df)
sns.lineplot(x="Date", y= "St. James Parish", data=df)
sns.lineplot(x="Date", y= "St. Tammany Parish", data=df)
sns.lineplot(x="Date", y= "Washington Parish", data=df)
sns.lineplot(x="Date", y= "West Feliciana Parish", data=df)
sns.lineplot(x="Date", y= "Jefferson Parish", data=df)
plt.axvline(x=2005,color = 'm',label = 'Katrina Hit')
plt.xlabel("Time")
plt.ylabel("Housing Price Index")
# Out:
# Text(0, 0.5, 'Housing Price Index')

# %%
parish= ['St. John the Baptist Parish'	,'West Batonrouge Parish'	,'	HPI La	','Batonrouge Parish'	,'Caddo Parish	Iberville Parish',	'Livingston Parish'	,
         'New Orleans Metairie Parish',	'Plaquemines Parish'	,'Pointe Coupee Parish',	'Shreveport Bossier Parish',	'St. James Parish',	'St. Tammany Parish'	,
         'Washington Parish',	'West Feliciana Parish'	,'Jefferson Paris']

# %%
#I use following codes to save some data frame data, in Google Colab. But it is saved in the "local file system", not in my computer nor Google Drive. How can I get the Excel file from there? Thanks!

writer = pd.ExcelWriter('hey.xlsx')
df.to_excel(writer)
writer.save()

# %%
#testing melting data to make graphing easier maybe?
test = df.drop(columns='Median House Income').melt(id_vars=["Date"], var_name="County", value_name="HPI")
fig, ax = plt.subplots(figsize=(30,10))
sns.lineplot(x="Date", y= 'HPI', data=test, hue='County')
plt.axvline(x=2005,color = 'm',label = 'Katrina Hit')
plt.axvline(x=2008,color = 'r',label = "'08 Recession")
plt.title("Housing Price Index",fontsize=40)
plt.legend(fontsize = 17)
plt.legend(bbox_to_anchor =(0.5,-0.27),ncol=4, loc='lower center')

# %%
df.to_csv('/content/drive/MyDrive/Team 55 [NEW]/Data/StLouis fed Housing data /fed_data.csv')
