# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd

import os
import gc
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv("/content/drive/MyDrive/Team 55 [NEW]/Data/dashboard_data/zillow.csv")

# %%
unaffected = ["Ascension Parish", "East Baton Rouge Parish", "East Feliciana Parish", "Iberville Parish", "Livingston Parish", "Pointe Coupee Parish", "St. Helena Parish", "West Baton Rouge Parish", "West Feliciana Parish","Caddo Parish"]

label_func = lambda x: 'Unaffected' if x in unaffected else 'Affected'

# Apply the lambda function to the column
df['Impact'] = df['County'].apply(label_func)

# %%
df.to_csv('/content/drive/MyDrive/Team 55 [NEW]/Data/dashboard_data/zillow2.csv', index=False)
